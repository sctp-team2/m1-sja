# %%
import duckdb
import pandas as pd
from pathlib import Path
# ---- from PKL ----
df = pd.read_pickle("../data/clean_job_step1.pkl")

df.head()
# Out:
#   employmentTypes metadata_expiryDate  metadata_isPostedOnBehalf  \
# 0       Permanent          2023-05-08                      False
# 1       Permanent          2023-05-08                      False
# 2       Full Time          2023-04-22                      False
# 3       Permanent          2023-05-08                      False
# 4       Full Time          2023-05-08                      False
#
#   metadata_jobPostId metadata_newPostingDate metadata_originalPostingDate  \
# 0   MCF-2023-0252866              2023-04-08                   2023-03-30
# 1   MCF-2023-0273977              2023-04-08                   2023-04-08
# 2   MCF-2023-0273994              2023-04-08                   2023-04-08
# 3   MCF-2023-0273991              2023-04-08                   2023-04-08
# 4   MCF-2023-0273976              2023-04-08                   2023-04-08
#
#    metadata_repostCount  metadata_totalNumberJobApplication  \
# 0                     2                                   5
# ...

# %%
# Numeric: salaries, experience, applications
df[["salary_minimum", "salary_maximum", "average_salary",
    "minimumYearsExperience", "metadata_totalNumberJobApplication",
    "metadata_totalNumberOfView", "numberOfVacancies", "category_1","category_2"]].describe()
# Out:
#        salary_minimum  salary_maximum  average_salary  minimumYearsExperience  \
# count    1.012928e+06    1.012928e+06    1.012928e+06            1.012928e+06
# mean     3.751730e+03    5.449035e+03    4.600383e+03            2.774770e+00
# std      2.070168e+03    3.183382e+03    2.579314e+03            2.443127e+00
# min      6.000000e+02    6.100000e+02    6.050000e+02            0.000000e+00
# 25%      2.500000e+03    3.500000e+03    3.000000e+03            1.000000e+00
# 50%      3.000000e+03    4.500000e+03    3.850000e+03            2.000000e+00
# 75%      4.500000e+03    6.500000e+03    5.500000e+03            4.000000e+00
# max      1.999900e+04    2.000000e+04    1.999950e+04            3.000000e+01
#
#        metadata_totalNumberJobApplication  metadata_totalNumberOfView  \
# count                        1.012928e+06                1.012928e+06
# mean                         2.101954e+00                2.638672e+01
# ...

# %%
# Categorical: who/what
for c in ["employmentTypes", "positionLevels", "status_jobStatus", "category_1", "category_2"]:
    print(f"\n{c}")
    print(df[c].value_counts(normalize=True).head(10) * 100)
# Out:
# employmentTypes
# employmentTypes
# Permanent                44.384793
# Full Time                37.983154
# Contract                 13.269650
# Part Time                 2.021565
# Temporary                 1.616304
# Internship/Attachment     0.483253
# Freelance                 0.150652
# Flexi-work                0.090628
# Name: proportion, dtype: float64
#
# positionLevels
# positionLevels
# Executive            24.713800
# Junior Executive     16.274701
# Non-executive        12.516092
# Fresh/entry level    10.870170
# Professional         10.671538
# Manager              10.616648
# Senior Executive      9.785296
# Middle Management     2.554871
# Senior Management     1.996884
# Name: proportion, dtype: float64
#
# status_jobStatus
# status_jobStatus
# Open       86.390543
# Closed     11.481665
# Re-open     2.127792
# Name: proportion, dtype: float64
#
# category_1
# category_1
# Admin / Secretarial                 9.766439
# ...

# %%
df.head()
# Out:
#   employmentTypes metadata_expiryDate  metadata_isPostedOnBehalf  \
# 0       Permanent          2023-05-08                      False
# 1       Permanent          2023-05-08                      False
# 2       Full Time          2023-04-22                      False
# 3       Permanent          2023-05-08                      False
# 4       Full Time          2023-05-08                      False
#
#   metadata_jobPostId metadata_newPostingDate metadata_originalPostingDate  \
# 0   MCF-2023-0252866              2023-04-08                   2023-03-30
# 1   MCF-2023-0273977              2023-04-08                   2023-04-08
# 2   MCF-2023-0273994              2023-04-08                   2023-04-08
# 3   MCF-2023-0273991              2023-04-08                   2023-04-08
# 4   MCF-2023-0273976              2023-04-08                   2023-04-08
#
#    metadata_repostCount  metadata_totalNumberJobApplication  \
# 0                     2                                   5
# ...
